# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
# Use the citipy module to determine city based on latitude and longitude.
import json
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude combinations. Declare each array as a variable.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.Unpack the zip object into a list so that you only have to create it once.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list. Use Enumerate 
#method to get the index of hte city and the city to create an endpoint URL.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | denpasar
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | athabasca
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | kashi
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | dondo
# Processing Record 10 of Set 1 | kamenka
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | klaksvik
# Processing Record 14 of Set 1 | abu kamal
# Processing Record 15 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 1 | anadyr
# Processing Record 17 of Set 1 | necochea
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | dikson
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | haines junction
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | aubenas
# Processing Record 25 of Set 1 | pevek
# Processing Record 26 of Set 1 | carnot
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | chuy
# Processing Record 31 of Set 1 | bandarbeyla
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | lazaro cardenas
# Processing Record 34 of Set 1 | bambous virieux
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | balaka
# Processing Record 37 of Set 1 | arraial do cabo
# Processing Record 38 of Set 1 | hamilton
# Processing Record 39 of Set 1 | tura
# Processing Record 40 of Set 1 | split
# Processing Record 41 of Set 1 | saint-paul
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | fort nelson
# Processing Record 44 of Set 1 | lompoc
# Processing Record 45 of Set 1 | sampit
# Processing Record 46 of Set 1 | hasaki
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | southbridge
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | georgetown
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | khatanga
# Processing Record 5 of Set 2 | kalabo
# Processing Record 6 of Set 2 | shache
# Processing Record 7 of Set 2 | tabas
# Processing Record 8 of Set 2 | inhambane
# Processing Record 9 of Set 2 | ancud
# Processing Record 10 of Set 2 | port macquarie
# Processing Record 11 of Set 2 | pacific grove
# Processing Record 12 of Set 2 | norman wells
# Processing Record 13 of Set 2 | xining
# Processing Record 14 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 2 | camabatela
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | bengkulu
# Processing Record 18 of Set 2 | kembolcha
# Processing Record 19 of Set 2 | rosarito
# Processing Record 20 of Set 2 | kapaa
# Processing Record 21 of Set 2 | tuatapere
# Processing Record 22 of Set 2 | gizo
# Processing Record 23 of Set 2 | kavieng
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | sabang
# Processing Record 26 of Set 2 | jingdezhen
# Processing Record 27 of Set 2 | tastur
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | salihli
# Processing Record 30 of Set 2 | isangel
# Processing Record 31 of Set 2 | ilulissat
# Processing Record 32 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 33 of Set 2 | awjilah
# Processing Record 34 of Set 2 | airai
# Processing Record 35 of Set 2 | longyearbyen
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | torbay
# Processing Record 39 of Set 2 | matadi
# Processing Record 40 of Set 2 | clyde river
# Processing Record 41 of Set 2 | atuona
# Processing Record 42 of Set 2 | ugoofaaru
# Processing Record 43 of Set 2 | kovdor
# Processing Record 44 of Set 2 | wade hampton
# Processing Record 45 of Set 2 | hailar
# Processing Record 46 of Set 2 | los llanos de aridane
# Processing Record 47 of Set 2 | tres arroyos
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | sagar
# Processing Record 50 of Set 2 | batemans bay
# Processing Record 1 of Set 3 | namibe
# Processing Record 2 of Set 3 | talnakh
# Processing Record 3 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | krasnokamensk
# Processing Record 6 of Set 3 | hithadhoo
# Processing Record 7 of Set 3 | truth or consequences
# Processing Record 8 of Set 3 | pitimbu
# Processing Record 9 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 3 | northam
# Processing Record 11 of Set 3 | larsnes
# Processing Record 12 of Set 3 | dmitrov
# Processing Record 13 of Set 3 | paamiut
# Processing Record 14 of Set 3 | port alfred
# Processing Record 15 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 3 | iqaluit
# Processing Record 17 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 18 of Set 3 | butaritari
# Processing Record 19 of Set 3 | plettenberg bay
# Processing Record 20 of Set 3 | dukat
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | arys
# Processing Record 23 of Set 3 | porosozero
# Processing Record 24 of Set 3 | narsaq
# Processing Record 25 of Set 3 | srednekolymsk
# Processing Record 26 of Set 3 | fortuna
# Processing Record 27 of Set 3 | skjervoy
# Processing Record 28 of Set 3 | portland
# Processing Record 29 of Set 3 | mezhdurechensk
# Processing Record 30 of Set 3 | katsuura
# Processing Record 31 of Set 3 | bonavista
# Processing Record 32 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 3 | gold coast
# Processing Record 34 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 35 of Set 3 | miraflores
# Processing Record 36 of Set 3 | pangnirtung
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | mahebourg
# Processing Record 39 of Set 3 | ostrovnoy
# Processing Record 40 of Set 3 | ponta do sol
# Processing Record 41 of Set 3 | guerrero negro
# Processing Record 42 of Set 3 | kabo
# Processing Record 43 of Set 3 | mayumba
# Processing Record 44 of Set 3 | colquechaca
# Processing Record 45 of Set 3 | college
# Processing Record 46 of Set 3 | presidencia roque saenz pena
# Processing Record 47 of Set 3 | kegayli
# City not found. Skipping...
# Processing Record 48 of Set 3 | betsiamites
# Processing Record 49 of Set 3 | tutoia
# Processing Record 50 of Set 3 | galich
# Processing Record 1 of Set 4 | mamlyutka
# Processing Record 2 of Set 4 | marawi
# Processing Record 3 of Set 4 | cherskiy
# Processing Record 4 of Set 4 | bor
# Processing Record 5 of Set 4 | bagdarin
# Processing Record 6 of Set 4 | beringovskiy
# Processing Record 7 of Set 4 | souillac
# Processing Record 8 of Set 4 | nsoko
# Processing Record 9 of Set 4 | murdochville
# Processing Record 10 of Set 4 | teguldet
# Processing Record 11 of Set 4 | bayan
# Processing Record 12 of Set 4 | wagga wagga
# Processing Record 13 of Set 4 | honningsvag
# Processing Record 14 of Set 4 | san andres
# Processing Record 15 of Set 4 | evensk
# Processing Record 16 of Set 4 | kodiak
# Processing Record 17 of Set 4 | faanui
# Processing Record 18 of Set 4 | paisley
# Processing Record 19 of Set 4 | dryden
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | lagoa
# Processing Record 23 of Set 4 | avera
# Processing Record 24 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 4 | bad neustadt
# City not found. Skipping...
# Processing Record 26 of Set 4 | ketchikan
# Processing Record 27 of Set 4 | puerto del rosario
# Processing Record 28 of Set 4 | hammerfest
# Processing Record 29 of Set 4 | berlevag
# Processing Record 30 of Set 4 | jardim
# Processing Record 31 of Set 4 | conceicao do araguaia
# Processing Record 32 of Set 4 | sumbe
# Processing Record 33 of Set 4 | qaanaaq
# Processing Record 34 of Set 4 | san luis
# Processing Record 35 of Set 4 | aswan
# Processing Record 36 of Set 4 | guacimo
# Processing Record 37 of Set 4 | bredasdorp
# Processing Record 38 of Set 4 | tripoli
# Processing Record 39 of Set 4 | comodoro rivadavia
# Processing Record 40 of Set 4 | montrose
# Processing Record 41 of Set 4 | oxford
# Processing Record 42 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 4 | lebu
# Processing Record 44 of Set 4 | coquimbo
# Processing Record 45 of Set 4 | tainan
# Processing Record 46 of Set 4 | provideniya
# Processing Record 47 of Set 4 | keetmanshoop
# Processing Record 48 of Set 4 | leningradskiy
# Processing Record 49 of Set 4 | adwa
# Processing Record 50 of Set 4 | sinnamary
# Processing Record 1 of Set 5 | kapuskasing
# Processing Record 2 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 5 | ambon
# Processing Record 4 of Set 5 | playa vicente
# Processing Record 5 of Set 5 | rio grande
# Processing Record 6 of Set 5 | vila velha
# Processing Record 7 of Set 5 | suntar
# Processing Record 8 of Set 5 | belmonte
# Processing Record 9 of Set 5 | pinega
# Processing Record 10 of Set 5 | watertown
# Processing Record 11 of Set 5 | geraldton
# Processing Record 12 of Set 5 | kavaratti
# Processing Record 13 of Set 5 | cidreira
# Processing Record 14 of Set 5 | mount isa
# Processing Record 15 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 5 | lorengau
# Processing Record 17 of Set 5 | bull savanna
# Processing Record 18 of Set 5 | kiama
# Processing Record 19 of Set 5 | rocha
# Processing Record 20 of Set 5 | cap malheureux
# Processing Record 21 of Set 5 | zhenhai
# Processing Record 22 of Set 5 | forest lake
# Processing Record 23 of Set 5 | xuddur
# Processing Record 24 of Set 5 | esna
# Processing Record 25 of Set 5 | ust-kuyga
# Processing Record 26 of Set 5 | san jeronimo
# Processing Record 27 of Set 5 | kayerkan
# Processing Record 28 of Set 5 | quchan
# Processing Record 29 of Set 5 | nurota
# Processing Record 30 of Set 5 | ixtapa
# Processing Record 31 of Set 5 | saint anthony
# Processing Record 32 of Set 5 | kemin
# Processing Record 33 of Set 5 | rawson
# Processing Record 34 of Set 5 | felipe carrillo puerto
# Processing Record 35 of Set 5 | amapa
# Processing Record 36 of Set 5 | cockburn town
# Processing Record 37 of Set 5 | mondlo
# Processing Record 38 of Set 5 | mar del plata
# Processing Record 39 of Set 5 | edendale
# Processing Record 40 of Set 5 | nikolskoye
# Processing Record 41 of Set 5 | sorong
# Processing Record 42 of Set 5 | san lazaro
# Processing Record 43 of Set 5 | vanimo
# Processing Record 44 of Set 5 | hilton head island
# Processing Record 45 of Set 5 | yellandu
# Processing Record 46 of Set 5 | miyako
# Processing Record 47 of Set 5 | greenville
# Processing Record 48 of Set 5 | ahipara
# Processing Record 49 of Set 5 | praia da vitoria
# Processing Record 50 of Set 5 | kirando
# Processing Record 1 of Set 6 | dir
# Processing Record 2 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 6 | grudziadz
# Processing Record 4 of Set 6 | fare
# Processing Record 5 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 6 | oreanda
# City not found. Skipping...
# Processing Record 7 of Set 6 | olafsvik
# Processing Record 8 of Set 6 | sistranda
# Processing Record 9 of Set 6 | monterey
# Processing Record 10 of Set 6 | katherine
# Processing Record 11 of Set 6 | havelock
# Processing Record 12 of Set 6 | yamada
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | new norfolk
# Processing Record 15 of Set 6 | sibu
# Processing Record 16 of Set 6 | henties bay
# Processing Record 17 of Set 6 | muros
# Processing Record 18 of Set 6 | berdigestyakh
# Processing Record 19 of Set 6 | bethel
# Processing Record 20 of Set 6 | salalah
# Processing Record 21 of Set 6 | santa cruz de la palma
# Processing Record 22 of Set 6 | carnarvon
# Processing Record 23 of Set 6 | beroroha
# Processing Record 24 of Set 6 | vilhena
# Processing Record 25 of Set 6 | igrim
# Processing Record 26 of Set 6 | toguchin
# Processing Record 27 of Set 6 | veraval
# Processing Record 28 of Set 6 | ponta delgada
# Processing Record 29 of Set 6 | shelburne
# Processing Record 30 of Set 6 | altay
# Processing Record 31 of Set 6 | vanavara
# Processing Record 32 of Set 6 | mehamn
# Processing Record 33 of Set 6 | kichera
# Processing Record 34 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 6 | yangjiang
# Processing Record 36 of Set 6 | port hardy
# Processing Record 37 of Set 6 | lieksa
# Processing Record 38 of Set 6 | ruthin
# Processing Record 39 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 6 | kununurra
# Processing Record 41 of Set 6 | san patricio
# Processing Record 42 of Set 6 | iwanai
# Processing Record 43 of Set 6 | itupiranga
# Processing Record 44 of Set 6 | rincon
# Processing Record 45 of Set 6 | yerbogachen
# Processing Record 46 of Set 6 | saint george
# Processing Record 47 of Set 6 | vavozh
# Processing Record 48 of Set 6 | palmer
# Processing Record 49 of Set 6 | ohara
# Processing Record 50 of Set 6 | mamallapuram
# Processing Record 1 of Set 7 | konigslutter
# City not found. Skipping...
# Processing Record 2 of Set 7 | owando
# Processing Record 3 of Set 7 | half moon bay
# Processing Record 4 of Set 7 | san carlos de bariloche
# Processing Record 5 of Set 7 | carambei
# Processing Record 6 of Set 7 | safaga
# Processing Record 7 of Set 7 | high level
# Processing Record 8 of Set 7 | inskoy
# Processing Record 9 of Set 7 | ponerihouen
# Processing Record 10 of Set 7 | baruun-urt
# Processing Record 11 of Set 7 | richards bay
# Processing Record 12 of Set 7 | margate
# Processing Record 13 of Set 7 | kalevala
# Processing Record 14 of Set 7 | marabba
# Processing Record 15 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 7 | ukiah
# Processing Record 17 of Set 7 | pangoa
# Processing Record 18 of Set 7 | vila franca do campo
# Processing Record 19 of Set 7 | yelatma
# Processing Record 20 of Set 7 | aberlour
# City not found. Skipping...
# Processing Record 21 of Set 7 | jackson
# Processing Record 22 of Set 7 | galle
# Processing Record 23 of Set 7 | shahrud
# Processing Record 24 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 7 | vrede
# Processing Record 26 of Set 7 | rabo de peixe
# Processing Record 27 of Set 7 | kahului
# Processing Record 28 of Set 7 | qasigiannguit
# Processing Record 29 of Set 7 | homer
# Processing Record 30 of Set 7 | lata
# Processing Record 31 of Set 7 | iracoubo
# Processing Record 32 of Set 7 | kudahuvadhoo
# Processing Record 33 of Set 7 | vuktyl
# Processing Record 34 of Set 7 | ende
# Processing Record 35 of Set 7 | torrelavega
# Processing Record 36 of Set 7 | vostok
# Processing Record 37 of Set 7 | acari
# Processing Record 38 of Set 7 | nouadhibou
# Processing Record 39 of Set 7 | pelaya
# Processing Record 40 of Set 7 | kuching
# Processing Record 41 of Set 7 | santa rosa
# Processing Record 42 of Set 7 | te anau
# Processing Record 43 of Set 7 | lookan
# Processing Record 44 of Set 7 | ust-karsk
# Processing Record 45 of Set 7 | lumby
# Processing Record 46 of Set 7 | viziru
# Processing Record 47 of Set 7 | palmerston
# Processing Record 48 of Set 7 | pierre
# Processing Record 49 of Set 7 | berea
# Processing Record 50 of Set 7 | zonguldak
# Processing Record 1 of Set 8 | codrington
# Processing Record 2 of Set 8 | mount gambier
# Processing Record 3 of Set 8 | luderitz
# Processing Record 4 of Set 8 | rundu
# Processing Record 5 of Set 8 | najran
# Processing Record 6 of Set 8 | srikakulam
# Processing Record 7 of Set 8 | jalu
# Processing Record 8 of Set 8 | floro
# Processing Record 9 of Set 8 | nobres
# Processing Record 10 of Set 8 | walvis bay
# Processing Record 11 of Set 8 | quatre cocos
# Processing Record 12 of Set 8 | kalmunai
# Processing Record 13 of Set 8 | pontianak
# Processing Record 14 of Set 8 | mersing
# Processing Record 15 of Set 8 | kyra
# Processing Record 16 of Set 8 | dwarka
# Processing Record 17 of Set 8 | lakatoro
# Processing Record 18 of Set 8 | zhangye
# Processing Record 19 of Set 8 | aljezur
# Processing Record 20 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 8 | road town
# Processing Record 22 of Set 8 | oeiras
# Processing Record 23 of Set 8 | vaitape
# Processing Record 24 of Set 8 | hun
# Processing Record 25 of Set 8 | sambava
# Processing Record 26 of Set 8 | miri
# Processing Record 27 of Set 8 | namatanai
# Processing Record 28 of Set 8 | vastervik
# City not found. Skipping...
# Processing Record 29 of Set 8 | aklavik
# Processing Record 30 of Set 8 | yunjinghong
# City not found. Skipping...
# Processing Record 31 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 32 of Set 8 | wynyard
# Processing Record 33 of Set 8 | takab
# Processing Record 34 of Set 8 | novaya ladoga
# Processing Record 35 of Set 8 | lavrentiya
# Processing Record 36 of Set 8 | grand-lahou
# Processing Record 37 of Set 8 | poum
# Processing Record 38 of Set 8 | japura
# Processing Record 39 of Set 8 | laizhou
# Processing Record 40 of Set 8 | sura
# Processing Record 41 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 8 | iquique
# Processing Record 43 of Set 8 | betul
# Processing Record 44 of Set 8 | jiayuguan
# Processing Record 45 of Set 8 | tomatlan
# Processing Record 46 of Set 8 | talara
# Processing Record 47 of Set 8 | soligalich
# Processing Record 48 of Set 8 | oga
# Processing Record 49 of Set 8 | sao joao da barra
# Processing Record 50 of Set 8 | beloha
# Processing Record 1 of Set 9 | prince rupert
# Processing Record 2 of Set 9 | araripina
# Processing Record 3 of Set 9 | dunmore town
# Processing Record 4 of Set 9 | goderich
# Processing Record 5 of Set 9 | puerto escondido
# Processing Record 6 of Set 9 | freeport
# Processing Record 7 of Set 9 | tapejara
# Processing Record 8 of Set 9 | zhangjiakou
# Processing Record 9 of Set 9 | blackwater
# Processing Record 10 of Set 9 | ratnagiri
# Processing Record 11 of Set 9 | upernavik
# Processing Record 12 of Set 9 | mwinilunga
# Processing Record 13 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 14 of Set 9 | diamantino
# Processing Record 15 of Set 9 | kasra
# City not found. Skipping...
# Processing Record 16 of Set 9 | waipawa
# Processing Record 17 of Set 9 | zyryanka
# Processing Record 18 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 9 | batamshinskiy
# Processing Record 20 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 9 | kousseri
# Processing Record 22 of Set 9 | saint-pierre
# Processing Record 23 of Set 9 | ulladulla
# Processing Record 24 of Set 9 | banjar
# Processing Record 25 of Set 9 | utamysh
# Processing Record 26 of Set 9 | valente
# Processing Record 27 of Set 9 | dali
# Processing Record 28 of Set 9 | victoria
# Processing Record 29 of Set 9 | hami
# Processing Record 30 of Set 9 | novolvovsk
# City not found. Skipping...
# Processing Record 31 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 9 | port hedland
# Processing Record 33 of Set 9 | washougal
# Processing Record 34 of Set 9 | vetluga
# Processing Record 35 of Set 9 | leshukonskoye
# Processing Record 36 of Set 9 | gwanda
# Processing Record 37 of Set 9 | jaisalmer
# Processing Record 38 of Set 9 | barcelos
# Processing Record 39 of Set 9 | mackay
# Processing Record 40 of Set 9 | casimiro castillo
# Processing Record 41 of Set 9 | ocos
# Processing Record 42 of Set 9 | thompson
# Processing Record 43 of Set 9 | kuybysheve
# Processing Record 44 of Set 9 | vista hermosa
# Processing Record 45 of Set 9 | boa vista
# Processing Record 46 of Set 9 | la ronge
# Processing Record 47 of Set 9 | russell
# Processing Record 48 of Set 9 | olavarria
# Processing Record 49 of Set 9 | maxixe
# Processing Record 50 of Set 9 | olinda
# Processing Record 1 of Set 10 | viana
# Processing Record 2 of Set 10 | antofagasta
# Processing Record 3 of Set 10 | southampton
# Processing Record 4 of Set 10 | ranau
# Processing Record 5 of Set 10 | kyle
# Processing Record 6 of Set 10 | touros
# Processing Record 7 of Set 10 | xenia
# Processing Record 8 of Set 10 | manta
# Processing Record 9 of Set 10 | kalianget
# Processing Record 10 of Set 10 | eregli
# Processing Record 11 of Set 10 | zhigansk
# Processing Record 12 of Set 10 | shitanjing
# Processing Record 13 of Set 10 | opuwo
# Processing Record 14 of Set 10 | barretos
# Processing Record 15 of Set 10 | deputatskiy
# Processing Record 16 of Set 10 | victor harbor
# Processing Record 17 of Set 10 | christchurch
# Processing Record 18 of Set 10 | cravo norte
# Processing Record 19 of Set 10 | kikwit
# Processing Record 20 of Set 10 | nchelenge
# Processing Record 21 of Set 10 | hovd
# Processing Record 22 of Set 10 | grand gaube
# Processing Record 23 of Set 10 | saint-augustin
# Processing Record 24 of Set 10 | manzil salim
# Processing Record 25 of Set 10 | matara
# Processing Record 26 of Set 10 | pisco
# Processing Record 27 of Set 10 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 28 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 29 of Set 10 | flinders
# Processing Record 30 of Set 10 | ingham
# Processing Record 31 of Set 10 | chulumani
# Processing Record 32 of Set 10 | stupino
# Processing Record 33 of Set 10 | paso de patria
# Processing Record 34 of Set 10 | chapais
# Processing Record 35 of Set 10 | empalme
# Processing Record 36 of Set 10 | arrifes
# Processing Record 37 of Set 10 | north platte
# Processing Record 38 of Set 10 | millinocket
# Processing Record 39 of Set 10 | yar-sale
# Processing Record 40 of Set 10 | ambovombe
# Processing Record 41 of Set 10 | lerwick
# Processing Record 42 of Set 10 | kruisfontein
# Processing Record 43 of Set 10 | majene
# Processing Record 44 of Set 10 | liberty
# Processing Record 45 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 46 of Set 10 | nanortalik
# Processing Record 47 of Set 10 | maragogi
# Processing Record 48 of Set 10 | pilao arcado
# City not found. Skipping...
# Processing Record 49 of Set 10 | moranbah
# Processing Record 50 of Set 10 | celestun
# Processing Record 1 of Set 11 | pangai
# Processing Record 2 of Set 11 | gravdal
# Processing Record 3 of Set 11 | esperance
# Processing Record 4 of Set 11 | nelson bay
# Processing Record 5 of Set 11 | sivas
# Processing Record 6 of Set 11 | chakia
# Processing Record 7 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 11 | tokonou
# Processing Record 9 of Set 11 | lensk
# Processing Record 10 of Set 11 | montevideo
# Processing Record 11 of Set 11 | ouadda
# Processing Record 12 of Set 11 | chumikan
# Processing Record 13 of Set 11 | yook
# Processing Record 14 of Set 11 | san vicente
# Processing Record 15 of Set 11 | ritchie
# Processing Record 16 of Set 11 | balingasay
# Processing Record 17 of Set 11 | jacareacanga
# Processing Record 18 of Set 11 | bondoukou
# Processing Record 19 of Set 11 | mazara del vallo
# Processing Record 20 of Set 11 | jutai
# Processing Record 21 of Set 11 | teya
# Processing Record 22 of Set 11 | bodden town
# Processing Record 23 of Set 11 | santa isabel do rio negro
# Processing Record 24 of Set 11 | guayaramerin
# Processing Record 25 of Set 11 | chadiza
# Processing Record 26 of Set 11 | cabo san lucas
# Processing Record 27 of Set 11 | ponazyrevo
# Processing Record 28 of Set 11 | dunedin
# Processing Record 29 of Set 11 | prainha
# Processing Record 30 of Set 11 | hofn
# Processing Record 31 of Set 11 | xiaoweizhai
# Processing Record 32 of Set 11 | talcahuano
# Processing Record 33 of Set 11 | alice springs
# Processing Record 34 of Set 11 | wodonga
# Processing Record 35 of Set 11 | noshiro
# Processing Record 36 of Set 11 | san rafael
# Processing Record 37 of Set 11 | the valley
# Processing Record 38 of Set 11 | roald
# Processing Record 39 of Set 11 | coihaique
# Processing Record 40 of Set 11 | akureyri
# Processing Record 41 of Set 11 | khandyga
# Processing Record 42 of Set 11 | vestmannaeyjar
# Processing Record 43 of Set 11 | boende
# Processing Record 44 of Set 11 | raga
# Processing Record 45 of Set 11 | juegang
# Processing Record 46 of Set 11 | east retford
# Processing Record 47 of Set 11 | etchojoa
# Processing Record 48 of Set 11 | puerto leguizamo
# Processing Record 49 of Set 11 | onguday
# Processing Record 50 of Set 11 | soyo
# Processing Record 1 of Set 12 | chuchkovo
# Processing Record 2 of Set 12 | husavik
# Processing Record 3 of Set 12 | faya
# Processing Record 4 of Set 12 | shu
# Processing Record 5 of Set 12 | porto murtinho
# Processing Record 6 of Set 12 | manaure
# Processing Record 7 of Set 12 | nerchinskiy zavod
# Processing Record 8 of Set 12 | barabai
# Processing Record 9 of Set 12 | egvekinot
# Processing Record 10 of Set 12 | sao lourenco do sul
# Processing Record 11 of Set 12 | san luis obispo
# Processing Record 12 of Set 12 | minab
# Processing Record 13 of Set 12 | tautira
# Processing Record 14 of Set 12 | pemangkat
# Processing Record 15 of Set 12 | kropotkin
# Processing Record 16 of Set 12 | arlit
# Processing Record 17 of Set 12 | beatrice
# Processing Record 18 of Set 12 | altar
# Processing Record 19 of Set 12 | oistins
# Processing Record 20 of Set 12 | bertoua
# Processing Record 21 of Set 12 | makakilo city
# Processing Record 22 of Set 12 | fuerte
# Processing Record 23 of Set 12 | filadelfia
# Processing Record 24 of Set 12 | arrecife
# Processing Record 25 of Set 12 | komsomolskiy
# Processing Record 26 of Set 12 | popondetta
# Processing Record 27 of Set 12 | port lincoln
# Processing Record 28 of Set 12 | bom jesus
# Processing Record 29 of Set 12 | tilichiki
# Processing Record 30 of Set 12 | fukuma
# Processing Record 31 of Set 12 | nizhnyaya tavda
# Processing Record 32 of Set 12 | chartres
# Processing Record 33 of Set 12 | bathsheba
# Processing Record 34 of Set 12 | camacha
# Processing Record 35 of Set 12 | marfino
# Processing Record 36 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 37 of Set 12 | huarmey
# Processing Record 38 of Set 12 | arcata
# Processing Record 39 of Set 12 | shuyskoye
# Processing Record 40 of Set 12 | iskateley
# Processing Record 41 of Set 12 | gampengrejo
# Processing Record 42 of Set 12 | kailua
# Processing Record 43 of Set 12 | kalamare
# Processing Record 44 of Set 12 | vidalia
# Processing Record 45 of Set 12 | beira
# Processing Record 46 of Set 12 | kaeo
# Processing Record 47 of Set 12 | lemesos
# City not found. Skipping...
# Processing Record 48 of Set 12 | long
# Processing Record 49 of Set 12 | carbonia
# Processing Record 50 of Set 12 | kurchum
# Processing Record 1 of Set 13 | tocopilla
# Processing Record 2 of Set 13 | hambantota
# Processing Record 3 of Set 13 | verkhoturye
# Processing Record 4 of Set 13 | honiara
# Processing Record 5 of Set 13 | sarkand
# Processing Record 6 of Set 13 | loreto
# Processing Record 7 of Set 13 | netrakona
# Processing Record 8 of Set 13 | okahandja
# Processing Record 9 of Set 13 | achisay
# City not found. Skipping...
# Processing Record 10 of Set 13 | buala
# Processing Record 11 of Set 13 | ati
# Processing Record 12 of Set 13 | litoral del san juan
# City not found. Skipping...
# Processing Record 13 of Set 13 | perth
# Processing Record 14 of Set 13 | cabatuan
# Processing Record 15 of Set 13 | waingapu
# Processing Record 16 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 13 | khash
# Processing Record 18 of Set 13 | jasper
# Processing Record 19 of Set 13 | ilawa
# Processing Record 20 of Set 13 | viedma
# Processing Record 21 of Set 13 | tadine
# Processing Record 22 of Set 13 | vestmanna
# Processing Record 23 of Set 13 | aksarka
# Processing Record 24 of Set 13 | tahe
# Processing Record 25 of Set 13 | santiago de cao
# Processing Record 26 of Set 13 | sao felix do xingu
# Processing Record 27 of Set 13 | albania
# Processing Record 28 of Set 13 | saleilua
# City not found. Skipping...
# Processing Record 29 of Set 13 | bassar
# Processing Record 30 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 13 | manokwari
# Processing Record 32 of Set 13 | dzaoudzi
# Processing Record 33 of Set 13 | gornozavodsk
# Processing Record 34 of Set 13 | leh
# Processing Record 35 of Set 13 | pilar
# Processing Record 36 of Set 13 | macomer
# Processing Record 37 of Set 13 | chipata
# Processing Record 38 of Set 13 | raudeberg
# Processing Record 39 of Set 13 | tete
# Processing Record 40 of Set 13 | hervey bay
# Processing Record 41 of Set 13 | mahibadhoo
# Processing Record 42 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 13 | broome
# Processing Record 44 of Set 13 | kargasok
# Processing Record 45 of Set 13 | eureka
# Processing Record 46 of Set 13 | emerald
# Processing Record 47 of Set 13 | matagami
# Processing Record 48 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 13 | lovozero
# Processing Record 50 of Set 13 | korla
# Processing Record 1 of Set 14 | palana
# Processing Record 2 of Set 14 | harper
# Processing Record 3 of Set 14 | khlung
# Processing Record 4 of Set 14 | ninghai
# Processing Record 5 of Set 14 | praya
# Processing Record 6 of Set 14 | port augusta
# Processing Record 7 of Set 14 | prince george
# Processing Record 8 of Set 14 | stettler
# Processing Record 9 of Set 14 | keti bandar
# Processing Record 10 of Set 14 | anupshahr
# Processing Record 11 of Set 14 | la reforma
# Processing Record 12 of Set 14 | lima
# Processing Record 13 of Set 14 | shingu
# Processing Record 14 of Set 14 | linfen
# Processing Record 15 of Set 14 | pandan
# Processing Record 16 of Set 14 | ambilobe
# Processing Record 17 of Set 14 | saint simons
# Processing Record 18 of Set 14 | karwar
# Processing Record 19 of Set 14 | hobyo
# Processing Record 20 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 21 of Set 14 | nemuro
# Processing Record 22 of Set 14 | virginia beach
# Processing Record 23 of Set 14 | riyadh
# Processing Record 24 of Set 14 | somanda
# Processing Record 25 of Set 14 | harsin
# Processing Record 26 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 14 | wucheng
# Processing Record 28 of Set 14 | calvia
# Processing Record 29 of Set 14 | sal rei
# Processing Record 30 of Set 14 | kidal
# Processing Record 31 of Set 14 | alofi
# Processing Record 32 of Set 14 | mazyr
# Processing Record 33 of Set 14 | hongjiang
# Processing Record 34 of Set 14 | higuey
# City not found. Skipping...
# Processing Record 35 of Set 14 | krasnoarmeyskoye
# Processing Record 36 of Set 14 | burica
# City not found. Skipping...
# Processing Record 37 of Set 14 | asau
# Processing Record 38 of Set 14 | atascocita
# Processing Record 39 of Set 14 | sao bento do sul
# Processing Record 40 of Set 14 | sovetskiy
# Processing Record 41 of Set 14 | daram
# Processing Record 42 of Set 14 | bac lieu
# Processing Record 43 of Set 14 | sioux lookout
# Processing Record 44 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 14 | osa
# Processing Record 46 of Set 14 | udachnyy
# Processing Record 47 of Set 14 | ambunti
# Processing Record 48 of Set 14 | dongsheng
# Processing Record 49 of Set 14 | creel
# Processing Record 50 of Set 14 | ahuimanu
# Processing Record 1 of Set 15 | abay
# Processing Record 2 of Set 15 | salta
# Processing Record 3 of Set 15 | wick
# Processing Record 4 of Set 15 | kazachinskoye
# Processing Record 5 of Set 15 | umm kaddadah
# Processing Record 6 of Set 15 | port moresby
# Processing Record 7 of Set 15 | sao filipe
# Processing Record 8 of Set 15 | manzanillo
# Processing Record 9 of Set 15 | arroyo
# Processing Record 10 of Set 15 | baykit
# Processing Record 11 of Set 15 | bauchi
# Processing Record 12 of Set 15 | tiznit
# Processing Record 13 of Set 15 | mogadishu
# Processing Record 14 of Set 15 | itigi
# Processing Record 15 of Set 15 | uyuni
# Processing Record 16 of Set 15 | zelenoborskiy
# Processing Record 17 of Set 15 | san quintin
# Processing Record 18 of Set 15 | kenora
# Processing Record 19 of Set 15 | lahan
# Processing Record 20 of Set 15 | buraydah
# Processing Record 21 of Set 15 | grindavik
# Processing Record 22 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 15 | sirjan
# Processing Record 24 of Set 15 | ilhabela
# Processing Record 25 of Set 15 | wangkui
# Processing Record 26 of Set 15 | whitianga
# Processing Record 27 of Set 15 | kang
# Processing Record 28 of Set 15 | batticaloa
# Processing Record 29 of Set 15 | atar
# Processing Record 30 of Set 15 | kapoeta
# Processing Record 31 of Set 15 | karangampel
# Processing Record 32 of Set 15 | goranboy
# Processing Record 33 of Set 15 | wewak
# Processing Record 34 of Set 15 | mitzic
# Processing Record 35 of Set 15 | betare oya
# Processing Record 36 of Set 15 | dhamtari
# Processing Record 37 of Set 15 | mana
# Processing Record 38 of Set 15 | mbuji-mayi
# Processing Record 39 of Set 15 | vercheres
# Processing Record 40 of Set 15 | omsukchan
# Processing Record 41 of Set 15 | beyneu
# Processing Record 42 of Set 15 | acarau
# Processing Record 43 of Set 15 | westport
# Processing Record 44 of Set 15 | caravelas
# Processing Record 45 of Set 15 | vanino
# Processing Record 46 of Set 15 | isilkul
# Processing Record 47 of Set 15 | hay river
# Processing Record 48 of Set 15 | yondo
# Processing Record 49 of Set 15 | vardo
# Processing Record 50 of Set 15 | millbrook
# Processing Record 1 of Set 16 | chara
# Processing Record 2 of Set 16 | tateyama
# Processing Record 3 of Set 16 | todos santos
# Processing Record 4 of Set 16 | krasnoselkup
# Processing Record 5 of Set 16 | san luis de gaceno
# Processing Record 6 of Set 16 | englewood
# Processing Record 7 of Set 16 | springbok
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_df = pd.DataFrame(city_data)
city_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Denpasar      ID  -8.6500  115.2167     83.86        74          20
# 1       Jamestown      US  42.0970  -79.2353     40.59        50         100
# 2           Bluff      NZ -46.6000  168.3333     57.47        90         100
# 3       Athabasca      CA  54.7169 -113.2854    -27.42       100          23
# 4  Saint-Philippe      RE -21.3585   55.7679     81.95        94         100
# 5           Kashi      CN  39.4547   75.9797     30.22        41         100
# 6           Sitka      US  57.0531 -135.3300     33.69        80         100
# 7         Rikitea      PF -23.1203 -134.9692     77.49        71          49
# 8           Dondo      MZ -19.6094   34.7431     85.95        59          31
# 9         Kamenka      RU  51.3223   42.7678     32.76        99         100
#
#    Wind Speed Current Description
# 0        2.30          few clouds
# 1        1.99     overcast clouds
# 2       18.32          light rain
# 3        5.55          few clouds
# 4       29.51       moderate rain
# 5        2.62     overcast clouds
# 6        8.05          light snow
# 7        6.64    scattered clouds
# 8       10.09    scattered clouds
# 9        8.66     overcast clouds

# %%
# Create the output file (CSV) & export file 
city_df.to_csv(path_or_buf='WeatherPy_Database.csv', index_label="City_ID")
